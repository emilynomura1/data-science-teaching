# %% [markdown]
# # Mini-Project - Week 3

# %% [markdown]
# Now you will practice some of the skills you've learned from lab 3 and apply them in a short mini-project! We will be using a dataset related to the direct marketing campaigns (i.e. phone calls) of a banking institution. [This](https://towardsdatascience.com/building-a-logistic-regression-in-python-step-by-step-becd4d56c9c8) article uses the dataset to run a logistic regression using a popular Python package/framework `scikit-learn`. However, we will be using `statsmodels` like in lab 3.

# %%
import pandas as pd
bank = pd.read_csv("https://raw.githubusercontent.com/madmashup/targeted-marketing-predictive-engine/master/banking.csv")
print(bank.head())
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# ...

# %%
# Libraries you may need
import statsmodels.api as sapi
import statsmodels.stats.api as sms
import seaborn as sns
import statsmodels.stats.outliers_influence as st_inf
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as mc
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from sklearn.metrics import classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.stats as statsmodstats
import numpy as np

# %% [markdown]
# ## Part 1 - Identifying potential models

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp_var_rate    41188 non-null  float64
#  16  cons_price_idx  41188 non-null  float64
# ...

# %% [markdown]
# There are many different types of variables for us to work with in this dataset. Some are continuous, some are categorical, and some are binary.
#
# ### <font color='green'> Question 1 </font>
# Come up with **3** potential variable combinations that could work for the following models using the banking dataset:
# - Multiple regression
# - One-way ANOVA
# - Logistic regression
#
# You will need to do some data exploration (i.e. looking at the values that certain variables take) before answering this question.
#
# List which variables you would use as predictors (the X variables) and which variable you want to predict (the Y variable) **for each model**.
#
# Note: *DO NOT RUN EACH OF THESE MODELS! You will only run **one** model and interpret it for this mini-project.*

# %% [markdown]
# ## Part 2 - Checking assumptions
# Suppose that we want to run a logistic regression on the `y` variable using `age` as a predictor.

# %% [markdown]
# ### <font color='green'> Question 2 </font>
# Check the six assumptions for logistic regression that you learned in lab 3. Your answer should include a mixture of code and writing (for most assumptions, a single sentence will suffice).

# %% [markdown]
# ## Part 3 - Interpreting your results:
# Is `age` a good predictor for whether or not a client subscribes to a term deposit?

# %% [markdown]
# ### <font color='green'> Question 3 </font>
# Now that we have checked the six assumptions, print the model summary and interpret the logistic regression results. In addition, return a classification report of your model. Again, your answer should consist of a mixture of code and writing.
